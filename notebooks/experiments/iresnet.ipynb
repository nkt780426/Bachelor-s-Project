# %% [markdown]
# # TMP

# %% [markdown]
# 1. Iresnet 50: pretrained
# 2. Resnext 50: pretrained
# 3. Wideresnext 50: pretrained
# 4. Efficientnet B4: pretrained
#
# pytorch: có code pre-trained, khó code do phải can thiệp sâu nhưng nhiều nơi hỗ trợ
#
# tensorflow: dễ code, nhiều công cụ cho production, tích hợp tốt với TPU với batch_size lớn

# %% [markdown]
# Malaria Detection: https://github.com/Neuralearn/deep-learning-with-tensorflow-2/blob/main/deep%20learning%20for%20computer%20vision/2-Malaria%20Detection%20by%20Neuralearn.ai-.ipynb
#
# Human Emotion Detection: https://github.com/Neuralearn/deep-learning-with-tensorflow-2/blob/main/deep%20learning%20for%20computer%20vision/4-Human%20Emotions%20Detection%20by%20Neuralearn.ai-.ipynb

# %% [markdown]
# Magface: https://github.com/IrvingMeng/MagFace
#
# Iresnet: https://github.com/iduta/iresnet

# %% [markdown]
# # Hyper parameter

# %%
CONFIGURATION = {
    "N_EPOCHS": 2000,
    "BATCH_SIZE": 16,
    "IM_SIZE": 224,
    "LEARNING_RATE": 0.01,
}

# %%
model = None

# %% [markdown]
# # MagFace loss
