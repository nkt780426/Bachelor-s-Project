# %%
from models.iresnet import iresnet50
from torchinfo import summary

# %%
model = iresnet50(pretrained=True)

summary(model=model, input_size=(16, 3, 224, 224), verbose=0)
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# iResNet                                  [16, 1000]                --
# ├─Conv2d: 1-1                            [16, 64, 112, 112]        9,408
# ├─BatchNorm2d: 1-2                       [16, 64, 112, 112]        128
# ├─ReLU: 1-3                              [16, 64, 112, 112]        --
# ├─Sequential: 1-4                        [16, 256, 56, 56]         --
# │    └─Bottleneck: 2-1                   [16, 256, 56, 56]         --
# │    │    └─Conv2d: 3-1                  [16, 64, 112, 112]        4,096
# │    │    └─BatchNorm2d: 3-2             [16, 64, 112, 112]        128
# │    │    └─ReLU: 3-3                    [16, 64, 112, 112]        --
# │    │    └─Conv2d: 3-4                  [16, 64, 56, 56]          36,864
# │    │    └─BatchNorm2d: 3-5             [16, 64, 56, 56]          128
# │    │    └─ReLU: 3-6                    [16, 64, 56, 56]          --
# ...

# %% [markdown]
# Resize ảnh sao cho cạnh nhỏ nhất là 256 và random crop 224
